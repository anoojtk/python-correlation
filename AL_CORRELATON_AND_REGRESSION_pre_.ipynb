# %% [markdown]
# <a href="https://colab.research.google.com/github/anoojtk/python-correlation/blob/main/AL_CORRELATON_AND_REGRESSION_pre_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv('/content/drive/MyDrive/data science/winequality-red_(2).csv')
df
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.4             0.700         0.00             1.9      0.076
# 1               7.8             0.880         0.00             2.6      0.098
# 2               7.8             0.760         0.04             2.3      0.092
# 3              11.2             0.280         0.56             1.9      0.075
# 4               7.4             0.700         0.00             1.9      0.076
# ...             ...               ...          ...             ...        ...
# 1594            6.2             0.600         0.08             2.0      0.090
# 1595            5.9             0.550         0.10             2.2      0.062
# 1596            6.3             0.510         0.13             2.3      0.076
# 1597            5.9             0.645         0.12             2.0      0.075
# 1598            6.0             0.310         0.47             3.6      0.067
#
#       free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                    11.0                  34.0  0.99780  3.51       0.56
# 1                    25.0                  67.0  0.99680  3.20       0.68
# 2                    15.0                  54.0  0.99700  3.26       0.65
# 3                    17.0                  60.0  0.99800  3.16       0.58
# 4                    11.0                  34.0  0.99780  3.51       0.56
# ...                   ...                   ...      ...   ...        ...
# 1594                 32.0                  44.0  0.99490  3.45       0.58
# 1595                 39.0                  51.0  0.99512  3.52       0.76
# 1596                 29.0                  40.0  0.99574  3.42       0.75
# 1597                 32.0                  44.0  0.99547  3.57       0.71
# 1598                 18.0                  42.0  0.99549  3.39       0.66
#
#       alcohol  quality
# 0         9.4        5
# 1         9.8        5
# 2         9.8        5
# 3         9.8        6
# 4         9.4        5
# ...       ...      ...
# 1594     10.5        5
# 1595     11.2        6
# 1596     11.0        6
# 1597     10.2        5
# 1598     11.0        6
#
# [1599 rows x 12 columns]

# %%
df.shape
# Out:
# (1599, 12)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1599 entries, 0 to 1598
# Data columns (total 12 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   fixed acidity         1599 non-null   float64
#  1   volatile acidity      1599 non-null   float64
#  2   citric acid           1599 non-null   float64
#  3   residual sugar        1599 non-null   float64
#  4   chlorides             1599 non-null   float64
#  5   free sulfur dioxide   1599 non-null   float64
#  6   total sulfur dioxide  1599 non-null   float64
#  7   density               1599 non-null   float64
#  8   pH                    1599 non-null   float64
#  9   sulphates             1599 non-null   float64
#  10  alcohol               1599 non-null   float64
#  11  quality               1599 non-null   int64
# dtypes: float64(11), int64(1)
# memory usage: 150.0 KB

# %%
df.isna().sum()
# Out:
# fixed acidity           0
# volatile acidity        0
# citric acid             0
# residual sugar          0
# chlorides               0
# free sulfur dioxide     0
# total sulfur dioxide    0
# density                 0
# pH                      0
# sulphates               0
# alcohol                 0
# quality                 0
# dtype: int64

# %%
df['quality'].unique()
# Out:
# array([5, 6, 7, 4, 8, 3])

# %%
df.describe()
# Out:
#        fixed acidity  volatile acidity  citric acid  residual sugar  \
# count    1599.000000       1599.000000  1599.000000     1599.000000
# mean        8.319637          0.527821     0.270976        2.538806
# std         1.741096          0.179060     0.194801        1.409928
# min         4.600000          0.120000     0.000000        0.900000
# 25%         7.100000          0.390000     0.090000        1.900000
# 50%         7.900000          0.520000     0.260000        2.200000
# 75%         9.200000          0.640000     0.420000        2.600000
# max        15.900000          1.580000     1.000000       15.500000
#
#          chlorides  free sulfur dioxide  total sulfur dioxide      density  \
# count  1599.000000          1599.000000           1599.000000  1599.000000
# mean      0.087467            15.874922             46.467792     0.996747
# std       0.047065            10.460157             32.895324     0.001887
# min       0.012000             1.000000              6.000000     0.990070
# 25%       0.070000             7.000000             22.000000     0.995600
# 50%       0.079000            14.000000             38.000000     0.996750
# 75%       0.090000            21.000000             62.000000     0.997835
# max       0.611000            72.000000            289.000000     1.003690
#
#                 pH    sulphates      alcohol      quality
# count  1599.000000  1599.000000  1599.000000  1599.000000
# mean      3.311113     0.658149    10.422983     5.636023
# std       0.154386     0.169507     1.065668     0.807569
# min       2.740000     0.330000     8.400000     3.000000
# 25%       3.210000     0.550000     9.500000     5.000000
# 50%       3.310000     0.620000    10.200000     6.000000
# 75%       3.400000     0.730000    11.100000     6.000000
# max       4.010000     2.000000    14.900000     8.000000

# %%
freqgraph=df.select_dtypes(include=['int32','int64','float'])
freqgraph.hist(figsize=(20,15))
plt.show()

# %%
df.isnull().sum()
# Out:
# fixed acidity           0
# volatile acidity        0
# citric acid             0
# residual sugar          0
# chlorides               0
# free sulfur dioxide     0
# total sulfur dioxide    0
# density                 0
# pH                      0
# sulphates               0
# alcohol                 0
# quality                 0
# dtype: int64

# %%
plt.boxplot(df['fixed acidity'])
plt.title('boxplot of fixed acidity')
plt.show()

# %%
q1=np.percentile(df['fixed acidity'],25,interpolation='midpoint')
q2=np.percentile(df['fixed acidity'],50,interpolation='midpoint')
q3=np.percentile(df['fixed acidity'],75,interpolation='midpoint')

print(q1)
print(q2)
print(q3)
# Out:
# 7.1
# 7.9
# 9.2
# <ipython-input-165-95fcaa0b8570>:1: DeprecationWarning: the `interpolation=` argument to percentile was renamed to `method=`, which has additional options.
# Users of the modes 'nearest', 'lower', 'higher', or 'midpoint' are encouraged to review the method they. (Deprecated NumPy 1.22)
#   q1=np.percentile(df['fixed acidity'],25,interpolation='midpoint')
# <ipython-input-165-95fcaa0b8570>:2: DeprecationWarning: the `interpolation=` argument to percentile was renamed to `method=`, which has additional options.
# Users of the modes 'nearest', 'lower', 'higher', or 'midpoint' are encouraged to review the method they. (Deprecated NumPy 1.22)
#   q2=np.percentile(df['fixed acidity'],50,interpolation='midpoint')
# <ipython-input-165-95fcaa0b8570>:3: DeprecationWarning: the `interpolation=` argument to percentile was renamed to `method=`, which has additional options.
# Users of the modes 'nearest', 'lower', 'higher', or 'midpoint' are encouraged to review the method they. (Deprecated NumPy 1.22)
#   q3=np.percentile(df['fixed acidity'],75,interpolation='midpoint')

# %%
iqr=q3-q1
low=q1-1.5*iqr
upper=q3+1.5*iqr
print(low)
print(upper)
# Out:
# 3.95
# 12.349999999999998

# %%
outlier=[]
for x in df['fixed acidity']:
  if((x>upper) or (x<low)):
    outlier.append(x)
outlier
# Out:
# [12.8,
#  12.8,
#  15.0,
#  15.0,
#  12.5,
#  13.3,
#  13.4,
#  12.4,
#  12.5,
#  13.8,
#  13.5,
#  12.6,
#  12.5,
#  12.8,
#  12.8,
#  14.0,
#  13.7,
#  13.7,
#  12.7,
#  12.5,
#  12.8,
#  12.6,
#  15.6,
#  12.5,
#  13.0,
#  12.5,
#  13.3,
#  12.4,
#  12.5,
#  12.9,
#  14.3,
#  12.4,
#  15.5,
#  15.5,
#  15.6,
#  13.0,
#  12.7,
#  13.0,
#  12.7,
#  12.4,
#  12.7,
#  13.2,
#  13.2,
#  13.2,
#  15.9,
#  13.3,
#  12.9,
#  12.6,
#  12.6]

# %%
ind=df['fixed acidity']>upper
df.loc[ind].index
# Out:
# Int64Index([ 205,  206,  243,  244,  264,  294,  328,  338,  339,  347,  353,
#              359,  363,  364,  366,  374,  381,  391,  394,  409,  429,  440,
#              442,  446,  470,  472,  509,  510,  516,  538,  544,  548,  554,
#              555,  557,  559,  560,  564,  565,  596,  599,  601,  603,  611,
#              652,  680,  811,  814, 1224],
#            dtype='int64')

# %%
df.drop([205,  206,  243,  244,  264,  294,  328,  338,  339,  347,  353,
             359,  363,  364,  366,  374,  381,  391,  394,  409,  429,  440,
             442,  446,  470,  472,  509,  510,  516,  538,  544,  548,  554,
             555,  557,  559,  560,  564,  565,  596,  599,  601,  603,  611,
             652,  680,  811,  814, 1224],inplace=True)

# %%
plt.boxplot(df['fixed acidity'])
plt.title('outlier removed fixed acidity')
plt.show()

# %%
plt.boxplot(df['volatile acidity'])
plt.title('boxplot of volatile acidity')
plt.show()

# %%
q1=np.percentile(df['volatile acidity'],25,interpolation='midpoint')
q2=np.percentile(df['volatile acidity'],50,interpolation='midpoint')
q3=np.percentile(df['volatile acidity'],75,interpolation='midpoint')

print(q1)
print(q2)
print(q3)
# Out:
# 0.395
# 0.52
# 0.64
# <ipython-input-172-506259c67411>:1: DeprecationWarning: the `interpolation=` argument to percentile was renamed to `method=`, which has additional options.
# Users of the modes 'nearest', 'lower', 'higher', or 'midpoint' are encouraged to review the method they. (Deprecated NumPy 1.22)
#   q1=np.percentile(df['volatile acidity'],25,interpolation='midpoint')
# <ipython-input-172-506259c67411>:2: DeprecationWarning: the `interpolation=` argument to percentile was renamed to `method=`, which has additional options.
# Users of the modes 'nearest', 'lower', 'higher', or 'midpoint' are encouraged to review the method they. (Deprecated NumPy 1.22)
#   q2=np.percentile(df['volatile acidity'],50,interpolation='midpoint')
# <ipython-input-172-506259c67411>:3: DeprecationWarning: the `interpolation=` argument to percentile was renamed to `method=`, which has additional options.
# Users of the modes 'nearest', 'lower', 'higher', or 'midpoint' are encouraged to review the method they. (Deprecated NumPy 1.22)
#   q3=np.percentile(df['volatile acidity'],75,interpolation='midpoint')

# %%
iqr=q3-q1
low=q1-1.5*iqr
upper=q3+1.5*iqr
print(low)
print(upper)
# Out:
# 0.027500000000000024
# 1.0075

# %%
outlier = []
for x in df['volatile acidity']:
  if((x>upper) or (x<low)):
    outlier.append(x)

outlier
# Out:
# [1.13,
#  1.02,
#  1.07,
#  1.33,
#  1.33,
#  1.04,
#  1.09,
#  1.04,
#  1.24,
#  1.185,
#  1.02,
#  1.035,
#  1.025,
#  1.115,
#  1.01,
#  1.02,
#  1.02,
#  1.58,
#  1.18,
#  1.04]

# %%
ind=df['volatile acidity']>upper
df.loc[ind].index
# Out:
# Int64Index([  38,   94,  120,  126,  127,  134,  199,  553,  672,  690,  700,
#              705,  710,  724,  861,  899, 1261, 1299, 1312, 1467],
#            dtype='int64')

# %%
df.drop([38,  94,  120,  126,  127,  134,  199,  553,  672,  690,  700,
             705,  710,  724,  861,  899, 1261, 1299, 1312, 1467],inplace=True)

# %%
plt.boxplot(df['volatile acidity'])
plt.title('outlier removed')
plt.show()

# %%
plt.boxplot(df['citric acid'])
plt.title('box plot ofcitric acid')
plt.show()

# %%
q1=np.percentile(df['citric acid'],25,interpolation='midpoint')
q2=np.percentile(df['citric acid'],50,interpolation='midpoint')
q3=np.percentile(df['citric acid'],75,interpolation='midpoint')
print(q1)
print(q2)
print(q3)
# Out:
# 0.09
# 0.25
# 0.41
# <ipython-input-179-7e7308387473>:1: DeprecationWarning: the `interpolation=` argument to percentile was renamed to `method=`, which has additional options.
# Users of the modes 'nearest', 'lower', 'higher', or 'midpoint' are encouraged to review the method they. (Deprecated NumPy 1.22)
#   q1=np.percentile(df['citric acid'],25,interpolation='midpoint')
# <ipython-input-179-7e7308387473>:2: DeprecationWarning: the `interpolation=` argument to percentile was renamed to `method=`, which has additional options.
# Users of the modes 'nearest', 'lower', 'higher', or 'midpoint' are encouraged to review the method they. (Deprecated NumPy 1.22)
#   q2=np.percentile(df['citric acid'],50,interpolation='midpoint')
# <ipython-input-179-7e7308387473>:3: DeprecationWarning: the `interpolation=` argument to percentile was renamed to `method=`, which has additional options.
# Users of the modes 'nearest', 'lower', 'higher', or 'midpoint' are encouraged to review the method they. (Deprecated NumPy 1.22)
#   q3=np.percentile(df['citric acid'],75,interpolation='midpoint')

# %%
iqr=q3-q1
lower=q1-1.5*iqr
upper=q3+1.5*iqr
print(lower)
print(upper)
# Out:
# -0.3899999999999999
# 0.8899999999999999

# %%
out=[]
for x in df['citric acid']:
  if((x>upper) or (x<lower)):
    out.append(x)
out
# Out:
# [1.0]

# %%
ind2=df['citric acid']>upper
df.loc[ind2].index
# Out:
# Int64Index([151], dtype='int64')

# %%
df.drop([151],inplace=True)

# %%
plt.boxplot(df['citric acid'])
plt.title('otlier removed')
plt.show()

# %%
plt.boxplot(df['residual sugar'])
plt.title('residual sugar')
plt.show()

# %%
q1=np.percentile(df['residual sugar'],25,interpolation='midpoint')
q2=np.percentile(df['residual sugar'],50,interpolation='midpoint')
q3=np.percentile(df['residual sugar'],75,interpolation='midpoint')
print(q1)
print(q2)
print(q3)
# Out:
# 1.9
# 2.2
# 2.6
# <ipython-input-186-02e0f1c4c9f4>:1: DeprecationWarning: the `interpolation=` argument to percentile was renamed to `method=`, which has additional options.
# Users of the modes 'nearest', 'lower', 'higher', or 'midpoint' are encouraged to review the method they. (Deprecated NumPy 1.22)
#   q1=np.percentile(df['residual sugar'],25,interpolation='midpoint')
# <ipython-input-186-02e0f1c4c9f4>:2: DeprecationWarning: the `interpolation=` argument to percentile was renamed to `method=`, which has additional options.
# Users of the modes 'nearest', 'lower', 'higher', or 'midpoint' are encouraged to review the method they. (Deprecated NumPy 1.22)
#   q2=np.percentile(df['residual sugar'],50,interpolation='midpoint')
# <ipython-input-186-02e0f1c4c9f4>:3: DeprecationWarning: the `interpolation=` argument to percentile was renamed to `method=`, which has additional options.
# Users of the modes 'nearest', 'lower', 'higher', or 'midpoint' are encouraged to review the method they. (Deprecated NumPy 1.22)
#   q3=np.percentile(df['residual sugar'],75,interpolation='midpoint')

# %%
iqr=q3-q1
low=q1-1.5*iqr
upp=q3-1.5*iqr
print(low)
print(upp)
# Out:
# 0.8499999999999996
# 1.5499999999999998

# %%
out1=[]
for x in df['residual sugar']:
  if((x<low) or (x>upp)):
    out1.append(x)

# %%
ind3=df['residual sugar']>upp
df.loc[ind3].index
# Out:
# Int64Index([   0,    1,    2,    3,    4,    5,    6,    8,    9,   10,
#             ...
#             1589, 1590, 1591, 1592, 1593, 1594, 1595, 1596, 1597, 1598],
#            dtype='int64', length=1451)

# %%
df.loc[ind3].index
# Out:
# Int64Index([   0,    1,    2,    3,    4,    5,    6,    8,    9,   10,
#             ...
#             1589, 1590, 1591, 1592, 1593, 1594, 1595, 1596, 1597, 1598],
#            dtype='int64', length=1451)

# %%
z=df.loc[ind3].index
z
# Out:
# Int64Index([   0,    1,    2,    3,    4,    5,    6,    8,    9,   10,
#             ...
#             1589, 1590, 1591, 1592, 1593, 1594, 1595, 1596, 1597, 1598],
#            dtype='int64', length=1451)

# %%
for i in z:

  df.drop(i,inplace=True)

# %%
plt.boxplot(df['residual sugar'])
plt.title('outlier removed')
plt.show()

# %%
plt.boxplot(df['chlorides'])
plt.title('boxplot')
plt.show()

# %%
q1=np.percentile(df['chlorides'],25,interpolation='midpoint')
q2=np.percentile(df['chlorides'],50,interpolation='midpoint')
q3=np.percentile(df['chlorides'],75,interpolation='midpoint')
print(q1)
print(q2)
print(q3)
# Out:
# 0.0579999999999999
# 0.07
# 0.08
# <ipython-input-195-e1c4b1d93e5a>:1: DeprecationWarning: the `interpolation=` argument to percentile was renamed to `method=`, which has additional options.
# Users of the modes 'nearest', 'lower', 'higher', or 'midpoint' are encouraged to review the method they. (Deprecated NumPy 1.22)
#   q1=np.percentile(df['chlorides'],25,interpolation='midpoint')
# <ipython-input-195-e1c4b1d93e5a>:2: DeprecationWarning: the `interpolation=` argument to percentile was renamed to `method=`, which has additional options.
# Users of the modes 'nearest', 'lower', 'higher', or 'midpoint' are encouraged to review the method they. (Deprecated NumPy 1.22)
#   q2=np.percentile(df['chlorides'],50,interpolation='midpoint')
# <ipython-input-195-e1c4b1d93e5a>:3: DeprecationWarning: the `interpolation=` argument to percentile was renamed to `method=`, which has additional options.
# Users of the modes 'nearest', 'lower', 'higher', or 'midpoint' are encouraged to review the method they. (Deprecated NumPy 1.22)
#   q3=np.percentile(df['chlorides'],75,interpolation='midpoint')

# %%
iqr=q3-q1
l=q1-1.5*iqr
u=q3+1.5*iqr
print(l)
print(u)
# Out:
# 0.024999999999999745
# 0.11300000000000016

# %%
out2=[]
for x in df['chlorides']:
  if((x<l) or (x>u)):
    out2.append(x)
out2
# Out:
# [0.145, 0.161, 0.414, 0.267]

# %%
ind4=df['chlorides']>u
df.loc[ind4].index
# Out:
# Int64Index([832, 916, 1051, 1374], dtype='int64')

# %%
df.drop([832, 916, 1051, 1374],inplace=True)

# %%
plt.boxplot(df['chlorides'])
plt.title('outlier removed')
plt.show()

# %%
plt.boxplot(df['free sulfur dioxide'])
plt.title('boxplot')
plt.show()

# %%
q1=np.percentile(df['free sulfur dioxide'],25,interpolation='midpoint')
q2=np.percentile(df['free sulfur dioxide'],50,interpolation='midpoint')
q3=np.percentile(df['free sulfur dioxide'],75,interpolation='midpoint')

print(q1)
print(q2)
print(q3)
# Out:
# 6.0
# 11.0
# 20.5
# <ipython-input-204-c044da63c1bf>:1: DeprecationWarning: the `interpolation=` argument to percentile was renamed to `method=`, which has additional options.
# Users of the modes 'nearest', 'lower', 'higher', or 'midpoint' are encouraged to review the method they. (Deprecated NumPy 1.22)
#   q1=np.percentile(df['free sulfur dioxide'],25,interpolation='midpoint')
# <ipython-input-204-c044da63c1bf>:2: DeprecationWarning: the `interpolation=` argument to percentile was renamed to `method=`, which has additional options.
# Users of the modes 'nearest', 'lower', 'higher', or 'midpoint' are encouraged to review the method they. (Deprecated NumPy 1.22)
#   q2=np.percentile(df['free sulfur dioxide'],50,interpolation='midpoint')
# <ipython-input-204-c044da63c1bf>:3: DeprecationWarning: the `interpolation=` argument to percentile was renamed to `method=`, which has additional options.
# Users of the modes 'nearest', 'lower', 'higher', or 'midpoint' are encouraged to review the method they. (Deprecated NumPy 1.22)
#   q3=np.percentile(df['free sulfur dioxide'],75,interpolation='midpoint')

# %%
iqr=q3-q1
low_limit=q1-1.5*iqr
up_limit=q3+1.5*iqr
print(low_limit)
print(up_limit)
# Out:
# -15.75
# 42.25

# %%
outlier = []
for x in df['free sulfur dioxide']:
  if((x>up_limit) or (x<low_limit)):
    outlier.append(x)

outlier
# Out:
# []

# %%
ind1=df['free sulfur dioxide']>up_limit
df.loc[ind1].index
# Out:
# Int64Index([], dtype='int64')

# %%
plt.boxplot(df['free sulfur dioxide'])
plt.title('outlier removed')
plt.show()

# %%
plt.boxplot(df['total sulfur dioxide'])
plt.title('boxplot')
plt.show()

# %%
q1=np.percentile(df['total sulfur dioxide'],25,interpolation='midpoint')
q2=np.percentile(df['total sulfur dioxide'],50,interpolation='midpoint')
q3=np.percentile(df['total sulfur dioxide'],75,interpolation='midpoint')

print(q1)
print(q2)
print(q3)
# Out:
# 18.0
# 27.0
# 46.0
# <ipython-input-211-0f29ffd7e579>:1: DeprecationWarning: the `interpolation=` argument to percentile was renamed to `method=`, which has additional options.
# Users of the modes 'nearest', 'lower', 'higher', or 'midpoint' are encouraged to review the method they. (Deprecated NumPy 1.22)
#   q1=np.percentile(df['total sulfur dioxide'],25,interpolation='midpoint')
# <ipython-input-211-0f29ffd7e579>:2: DeprecationWarning: the `interpolation=` argument to percentile was renamed to `method=`, which has additional options.
# Users of the modes 'nearest', 'lower', 'higher', or 'midpoint' are encouraged to review the method they. (Deprecated NumPy 1.22)
#   q2=np.percentile(df['total sulfur dioxide'],50,interpolation='midpoint')
# <ipython-input-211-0f29ffd7e579>:3: DeprecationWarning: the `interpolation=` argument to percentile was renamed to `method=`, which has additional options.
# Users of the modes 'nearest', 'lower', 'higher', or 'midpoint' are encouraged to review the method they. (Deprecated NumPy 1.22)
#   q3=np.percentile(df['total sulfur dioxide'],75,interpolation='midpoint')

# %%
iqr=q3-q1
low=q1-1.5*iqr
up=q3+1.5*iqr
print(low)
print(up)
# Out:
# -24.0
# 88.0

# %%
outlier=[]
for x in df['total sulfur dioxide']:
  if((x>up) or (x<low)):
    outlier.append(x)
outlier
# Out:
# [96.0, 119.0, 93.0, 165.0, 109.0, 109.0]

# %%
ind1=df['total sulfur dioxide']>up_limit
df.loc[ind1].index
# Out:
# Int64Index([  49,   79,  175,  198,  202,  354,  390,  439,  469,  695,  835,
#              853,  854,  856,  871, 1001, 1017, 1018, 1219, 1309, 1316, 1321],
#            dtype='int64')

# %%
df.drop([49,   79,  175,  198,  202,  354,  390,  439,  469,  695,  835,
             853,  854,  856,  871, 1001, 1017, 1018, 1219, 1309, 1316, 1321 ],inplace=True)

# %%
plt.boxplot(df['total sulfur dioxide'])
plt.title('outlier removed')
plt.show()

# %%
plt.boxplot(df['density'])
plt.show()

# %%
q1=np.percentile(df['density'],25,interpolation='midpoint')
q2=np.percentile(df['density'],50,interpolation='midpoint')
q3=np.percentile(df['density'],75,interpolation='midpoint')

print(q1)
print(q2)
print(q3)
# Out:
# 0.994595
# 0.995525
# 0.9969250000000001
# <ipython-input-219-f6a9ddcb8bc9>:1: DeprecationWarning: the `interpolation=` argument to percentile was renamed to `method=`, which has additional options.
# Users of the modes 'nearest', 'lower', 'higher', or 'midpoint' are encouraged to review the method they. (Deprecated NumPy 1.22)
#   q1=np.percentile(df['density'],25,interpolation='midpoint')
# <ipython-input-219-f6a9ddcb8bc9>:2: DeprecationWarning: the `interpolation=` argument to percentile was renamed to `method=`, which has additional options.
# Users of the modes 'nearest', 'lower', 'higher', or 'midpoint' are encouraged to review the method they. (Deprecated NumPy 1.22)
#   q2=np.percentile(df['density'],50,interpolation='midpoint')
# <ipython-input-219-f6a9ddcb8bc9>:3: DeprecationWarning: the `interpolation=` argument to percentile was renamed to `method=`, which has additional options.
# Users of the modes 'nearest', 'lower', 'higher', or 'midpoint' are encouraged to review the method they. (Deprecated NumPy 1.22)
#   q3=np.percentile(df['density'],75,interpolation='midpoint')

# %%
iqr=q3-q1
low_limit=q1-1.5*iqr
up_limit=q3+1.5*iqr
print(low_limit)
print(up_limit)
# Out:
# 0.9910999999999999
# 1.00042

# %%
outlier=[]
for x in df['density']:
  if((x>up_limit) or (x<low_limit)):
    outlier.append(x)
outlier
# Out:
# []

# %%
ind1=df['density']>up_limit
df.loc[ind1].index
# Out:
# Int64Index([], dtype='int64')

# %%
ind2=df['density']<low_limit
df.loc[ind2].index
# Out:
# Int64Index([], dtype='int64')

# %%
plt.boxplot(df['density'])
plt.show()

# %%
plt.boxplot(df['pH'])
plt.title('box')
plt.show()

# %%
q1=np.percentile(df['pH'],25,interpolation='midpoint')
q2=np.percentile(df['pH'],50,interpolation='midpoint')
q3=np.percentile(df['pH'],75,interpolation='midpoint')

print(q1)
print(q2)
print(q3)
# Out:
# 3.16
# 3.255
# 3.355
# <ipython-input-228-ecbc2d88dd96>:1: DeprecationWarning: the `interpolation=` argument to percentile was renamed to `method=`, which has additional options.
# Users of the modes 'nearest', 'lower', 'higher', or 'midpoint' are encouraged to review the method they. (Deprecated NumPy 1.22)
#   q1=np.percentile(df['pH'],25,interpolation='midpoint')
# <ipython-input-228-ecbc2d88dd96>:2: DeprecationWarning: the `interpolation=` argument to percentile was renamed to `method=`, which has additional options.
# Users of the modes 'nearest', 'lower', 'higher', or 'midpoint' are encouraged to review the method they. (Deprecated NumPy 1.22)
#   q2=np.percentile(df['pH'],50,interpolation='midpoint')
# <ipython-input-228-ecbc2d88dd96>:3: DeprecationWarning: the `interpolation=` argument to percentile was renamed to `method=`, which has additional options.
# Users of the modes 'nearest', 'lower', 'higher', or 'midpoint' are encouraged to review the method they. (Deprecated NumPy 1.22)
#   q3=np.percentile(df['pH'],75,interpolation='midpoint')

# %%
iqr=q3-q1
low_limit=q1-1.5*iqr
up_limit=q3+1.5*iqr
print(low_limit)
print(up_limit)
# Out:
# 2.8675000000000006
# 3.6475

# %%
outlier=[]
for x in df['pH']:
  if((x>up_limit) or (x<low_limit)):
    outlier.append(x)
outlier
# Out:
# [3.66]

# %%
ind1=df['pH']>up_limit
df.loc[ind1].index
# Out:
# Int64Index([1480], dtype='int64')

# %%
ind2=df['pH']<low_limit
df.loc[ind2].index
# Out:
# Int64Index([], dtype='int64')

# %%
plt.boxplot(df['pH'])
plt.show()

# %%
plt.boxplot(df['sulphates'])
plt.title('boxplot')
plt.show()

# %%
q1=np.percentile(df['sulphates'],25,interpolation='midpoint')
q2=np.percentile(df['sulphates'],50,interpolation='midpoint')
q3=np.percentile(df['sulphates'],75,interpolation='midpoint')

print(q1)
print(q2)
print(q3)
# Out:
# 0.52
# 0.59
# 0.7
# <ipython-input-236-3397899c3b5a>:1: DeprecationWarning: the `interpolation=` argument to percentile was renamed to `method=`, which has additional options.
# Users of the modes 'nearest', 'lower', 'higher', or 'midpoint' are encouraged to review the method they. (Deprecated NumPy 1.22)
#   q1=np.percentile(df['sulphates'],25,interpolation='midpoint')
# <ipython-input-236-3397899c3b5a>:2: DeprecationWarning: the `interpolation=` argument to percentile was renamed to `method=`, which has additional options.
# Users of the modes 'nearest', 'lower', 'higher', or 'midpoint' are encouraged to review the method they. (Deprecated NumPy 1.22)
#   q2=np.percentile(df['sulphates'],50,interpolation='midpoint')
# <ipython-input-236-3397899c3b5a>:3: DeprecationWarning: the `interpolation=` argument to percentile was renamed to `method=`, which has additional options.
# Users of the modes 'nearest', 'lower', 'higher', or 'midpoint' are encouraged to review the method they. (Deprecated NumPy 1.22)
#   q3=np.percentile(df['sulphates'],75,interpolation='midpoint')

# %%
iqr=q3-q1
low_limit=q1-1.5*iqr
up_limit=q3+1.5*iqr
print(low_limit)
print(up_limit)
# Out:
# 0.2500000000000001
# 0.9699999999999999

# %%
outlier=[]
for x in df['sulphates']:
  if((x>up_limit) or (x<low_limit)):
    outlier.append(x)
outlier
# Out:
# [1.08]

# %%
ind1=df['sulphates']>up_limit
df.loc[ind1].index
# Out:
# Int64Index([161], dtype='int64')

# %%
df.drop([ 161],inplace=True)

# %%
plt.boxplot(df['sulphates'])
plt.show()

# %%
plt.boxplot(df['alcohol'])
plt.title('boxplot')
plt.show()

# %%
q1=np.percentile(df['alcohol'],25,interpolation='midpoint')
q2=np.percentile(df['alcohol'],50,interpolation='midpoint')
q3=np.percentile(df['alcohol'],75,interpolation='midpoint')

print(q1)
print(q2)
print(q3)
# Out:
# 9.6
# 10.0
# 10.4
# <ipython-input-244-f953532d32d7>:1: DeprecationWarning: the `interpolation=` argument to percentile was renamed to `method=`, which has additional options.
# Users of the modes 'nearest', 'lower', 'higher', or 'midpoint' are encouraged to review the method they. (Deprecated NumPy 1.22)
#   q1=np.percentile(df['alcohol'],25,interpolation='midpoint')
# <ipython-input-244-f953532d32d7>:2: DeprecationWarning: the `interpolation=` argument to percentile was renamed to `method=`, which has additional options.
# Users of the modes 'nearest', 'lower', 'higher', or 'midpoint' are encouraged to review the method they. (Deprecated NumPy 1.22)
#   q2=np.percentile(df['alcohol'],50,interpolation='midpoint')
# <ipython-input-244-f953532d32d7>:3: DeprecationWarning: the `interpolation=` argument to percentile was renamed to `method=`, which has additional options.
# Users of the modes 'nearest', 'lower', 'higher', or 'midpoint' are encouraged to review the method they. (Deprecated NumPy 1.22)
#   q3=np.percentile(df['alcohol'],75,interpolation='midpoint')

# %%
iqr=q3-q1
low_limit=q1-1.5*iqr
up_limit=q3+1.5*iqr
print(low_limit)
print(up_limit)
# Out:
# 8.399999999999999
# 11.600000000000001

# %%
outlier=[]
for x in df['alcohol']:
  if((x>up_limit) or (x<low_limit)):
    outlier.append(x)
outlier
# Out:
# [11.8, 12.3, 12.2]

# %%
ind1=df['alcohol']>up_limit
df.loc[ind1].index
# Out:
# Int64Index([1080, 1122, 1298], dtype='int64')

# %%
df.drop([1080, 1122, 1298],inplace=True)

# %%
plt.boxplot(df['alcohol'])
plt.show()

# %%
corematrix=df.corr()
plt.subplots(figsize=(20,8))
sns.heatmap(corematrix,vmin=-.7,vmax=0.7,annot=True,linewidths=0.2)
plt.show()

# %%
df1=df.drop(['fixed acidity','density','free sulfur dioxide'],axis=1)
df1.columns
# Out:
# Index(['volatile acidity', 'citric acid', 'residual sugar', 'chlorides',
#        'total sulfur dioxide', 'pH', 'sulphates', 'alcohol', 'quality'],
#       dtype='object')

# %%
y=df1['quality']
x=df1.drop(['quality'],axis=1)

# %%
x.shape
# Out:
# (48, 8)

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,random_state=42,test_size=0.25)

# %%
x_train
# Out:
#       volatile acidity  citric acid  residual sugar  chlorides  \
# 301              0.180         0.48             1.5      0.068
# 1376             0.885         0.20             1.4      0.086
# 1253             0.660         0.00             1.4      0.096
# 660              0.520         0.07             1.4      0.074
# 979              0.450         0.49             1.4      0.075
# 1483             0.330         0.44             1.5      0.042
# 914              0.305         0.39             1.2      0.059
# 613              0.390         0.38             1.5      0.058
# 937              0.630         0.50             1.4      0.071
# 1112             0.330         0.41             1.5      0.056
# 1200             0.570         0.21             1.5      0.069
# 1494             0.310         0.09             1.4      0.066
# 7                0.650         0.00             1.2      0.065
# 1197             0.570         0.21             1.5      0.069
# 1161             0.450         0.43             1.4      0.076
# 222              0.610         0.04             1.5      0.057
# 657              0.500         0.59             1.4      0.073
# 1336             0.500         0.00             1.4      0.057
# 25               0.390         0.16             1.4      0.080
# 1480             0.620         0.03             1.5      0.080
# 998              0.840         0.34             1.4      0.050
# 66               0.520         0.11             1.5      0.079
# 1338             0.500         0.00             1.4      0.057
# 1337             0.500         0.00             1.4      0.057
# 1070             0.330         0.45             1.5      0.057
# 1424             0.260         0.37             1.4      0.076
# 635              0.840         0.00             1.4      0.065
# 1045             0.440         0.00             1.4      0.070
# 984              0.450         0.49             1.4      0.075
# 1500             0.725         0.04             1.5      0.076
# 989              0.295         0.40             1.5      0.073
# 405              0.310         0.46             1.4      0.059
# 1425             0.260         0.37             1.4      0.076
# 909              0.305         0.39             1.2      0.059
# 1110             0.530         0.00             1.4      0.070
# 1362             0.475         0.40             1.4      0.091
#
#       total sulfur dioxide    pH  sulphates    alcohol
# 301                   15.0  3.22       0.64  10.100000
# 1376                  31.0  3.11       0.46  10.000000
# 1253                  13.0  3.43       0.58   9.500000
# 660                   20.0  3.32       0.81   9.600000
# 979                    6.0  3.13       0.63  10.400000
# 1483                  12.0  3.35       0.61  10.700000
# 914                   11.0  3.29       0.52  11.500000
# 613                   29.0  3.26       0.74   9.800000
# 937                   26.0  3.07       0.60  10.400000
# 1112                  35.0  3.29       0.71  11.000000
# 1200                   9.0  3.16       0.54   9.800000
# 1494                  28.0  3.42       0.70  10.000000
# 7                     21.0  3.39       0.47  10.000000
# 1197                   9.0  3.16       0.54   9.800000
# 1161                  21.0  3.21       0.75  10.200000
# 222                   10.0  3.42       0.60   9.500000
# 657                   42.0  2.92       0.68  10.500000
# 1336                  26.0  3.36       0.45   9.500000
# 25                    23.0  3.34       0.56   9.300000
# 1480                  13.0  3.66       0.62  10.100000
# 998                   10.0  3.12       0.48   9.100000
# 66                    39.0  3.42       0.58   9.600000
# 1338                  26.0  3.36       0.45   9.500000
# 1337                  26.0  3.36       0.45   9.500000
# 1070                  37.0  3.18       0.89  11.100000
# 1424                  23.0  3.26       0.70   9.600000
# 635                   33.0  3.27       0.55   9.700000
# 1045                  38.0  3.32       0.58  11.400000
# 984                    6.0  3.13       0.63  10.400000
# 1500                  15.0  3.26       0.53   9.600000
# 989                   21.0  3.14       0.51  10.900000
# 405                   25.0  3.36       0.76  10.100000
# 1425                  23.0  3.26       0.70   9.600000
# 909                   11.0  3.29       0.52  11.500000
# 1110                  14.0  3.25       0.64  10.000000
# 1362                  28.0  3.07       0.65  10.033333

# %%
x_test
# Out:
#       volatile acidity  citric acid  residual sugar  chlorides  \
# 1099             0.520         0.38             1.5      0.096
# 1392             0.620         0.06             1.3      0.070
# 1097             0.520         0.38             1.5      0.096
# 1470             0.690         0.11             1.4      0.084
# 1088             0.410         0.54             1.5      0.095
# 1359             0.475         0.40             1.4      0.091
# 658              0.520         0.07             1.4      0.074
# 986              0.340         0.39             1.4      0.066
# 200              0.320         0.47             1.4      0.056
# 1089             0.410         0.54             1.5      0.095
# 428              0.520         0.33             1.3      0.070
# 133              0.500         0.01             1.5      0.060
#
#       total sulfur dioxide    pH  sulphates    alcohol
# 1099                  18.0  3.20       0.52   9.400000
# 1392                  12.0  3.17       0.48   9.800000
# 1097                  18.0  3.20       0.52   9.400000
# 1470                  24.0  2.88       0.47   9.700000
# 1088                  41.0  3.02       0.76   9.900000
# 1359                  28.0  3.07       0.65  10.033333
# 658                   20.0  3.32       0.81   9.600000
# 986                    7.0  3.19       0.55  11.400000
# 200                   24.0  3.22       0.82  10.300000
# 1089                  41.0  3.02       0.76   9.900000
# 428                   30.0  3.24       0.60   9.300000
# 133                   26.0  3.40       0.58   9.800000

# %%
y_train
# Out:
# 301     6
# 1376    5
# 1253    5
# 660     6
# 979     5
# 1483    5
# 914     6
# 613     5
# 937     4
# 1112    6
# 1200    6
# 1494    7
# 7       7
# 1197    6
# 1161    6
# 222     5
# 657     7
# 1336    5
# 25      5
# 1480    4
# 998     6
# 66      5
# 1338    5
# 1337    5
# 1070    7
# 1424    6
# 635     5
# 1045    6
# 984     5
# 1500    5
# 989     6
# 405     6
# 1425    6
# 909     6
# 1110    6
# 1362    6
# Name: quality, dtype: int64

# %%
y_test
# Out:
# 1099    5
# 1392    5
# 1097    5
# 1470    5
# 1088    7
# 1359    6
# 658     6
# 986     7
# 200     7
# 1089    7
# 428     5
# 133     6
# Name: quality, dtype: int64

# %%
from sklearn import linear_model
lr=linear_model.LinearRegression()

# %%
model=lr.fit(x_train,y_train)

# %%
prediction=model.predict(x_test)

# %%
print(y_test)
# Out:
# 1099    5
# 1392    5
# 1097    5
# 1470    5
# 1088    7
# 1359    6
# 658     6
# 986     7
# 200     7
# 1089    7
# 428     5
# 133     6
# Name: quality, dtype: int64

# %%
print(prediction)
# Out:
# [4.4882408  6.11070124 4.4882408  6.45362047 5.89153693 5.92358652
#  6.38835586 5.76295682 6.48474672 5.89153693 5.77163894 5.39971828]

# %%
from sklearn.metrics import mean_squared_error
print('MSC:',mean_squared_error(y_test,prediction))
# Out:
# MSC: 0.7696692777351689

# %%
from sklearn.metrics import r2_score
print('R squared values is :',r2_score(y_test,prediction))
# Out:
# R squared values is : -0.03581659807349813

# %%
x.describe()
# Out:
#        volatile acidity  citric acid  residual sugar  chlorides  \
# count         48.000000    48.000000       48.000000  48.000000
# mean           0.484896     0.262917        1.418750   0.071250
# std            0.158418     0.197160        0.078973   0.013192
# min            0.180000     0.000000        1.200000   0.042000
# 25%            0.337500     0.055000        1.400000   0.059000
# 50%            0.500000     0.355000        1.400000   0.070000
# 75%            0.570000     0.415000        1.500000   0.076750
# max            0.885000     0.590000        1.500000   0.096000
#
#        total sulfur dioxide         pH  sulphates    alcohol
# count             48.000000  48.000000  48.000000  48.000000
# mean              22.166667   3.239375   0.611458  10.038889
# std               10.057988   0.144140   0.112609   0.616608
# min                6.000000   2.880000   0.450000   9.100000
# 25%               13.000000   3.155000   0.520000   9.600000
# 50%               23.000000   3.255000   0.600000   9.900000
# 75%               28.000000   3.342500   0.700000  10.325000
# max               42.000000   3.660000   0.890000  11.500000

# %%
type(x)
# Out:
# pandas.core.frame.DataFrame

# %%
from sklearn import preprocessing
standards=preprocessing.StandardScaler()
x=standards.fit_transform(x)

# %%
x=pd.DataFrame(x)
x.describe()
# Out:
#                   0             1             2          3             4  \
# count  4.800000e+01  4.800000e+01  4.800000e+01  48.000000  4.800000e+01
# mean   1.757853e-16 -1.017704e-16 -7.401487e-17   0.000000 -1.017704e-16
# std    1.010582e+00  1.010582e+00  1.010582e+00   1.010582  1.010582e+00
# min   -1.944996e+00 -1.347629e+00 -2.799254e+00  -2.240765 -1.624355e+00
# 25%   -9.402695e-01 -1.065716e+00 -2.399360e-01  -0.938440 -9.210263e-01
# 50%    9.635270e-02  4.719906e-01 -2.399360e-01  -0.095759  8.372966e-02
# 75%    5.428977e-01  7.795320e-01  1.039723e+00   0.421340  5.861076e-01
# max    2.552350e+00  1.676528e+00  1.039723e+00   1.896032  1.992766e+00
#
#                   5             6             7
# count  4.800000e+01  4.800000e+01  4.800000e+01
# mean  -2.535009e-15  9.251859e-17 -5.551115e-16
# std    1.010582e+00  1.010582e+00  1.010582e+00
# min   -2.519629e+00 -1.448968e+00 -1.538782e+00
# 25%   -5.915650e-01 -8.207701e-01 -7.193122e-01
# 50%    1.095491e-01 -1.028300e-01 -2.276304e-01
# 75%    7.230239e-01  7.945952e-01  4.689187e-01
# max    2.949061e+00  2.499703e+00  2.394672e+00

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,random_state=42,test_size=0.2)
lr=linear_model.LinearRegression()
model=lr.fit(x_train,y_train)
pre=model.predict(x_test)
print('MSE is :',mean_squared_error(y_test,pre))
print('R error is ',r2_score(y_test,pre))
# Out:
# MSE is : 0.8677287714885195
# R error is  -0.0846609643606493

# %%
x=df.drop('quality',axis=1)
x.describe()
# Out:
#        fixed acidity  volatile acidity  citric acid  residual sugar  \
# count      48.000000         48.000000    48.000000       48.000000
# mean        8.568750          0.484896     0.262917        1.418750
# std         1.870164          0.158418     0.197160        0.078973
# min         5.600000          0.180000     0.000000        1.200000
# 25%         7.275000          0.337500     0.055000        1.400000
# 50%         8.250000          0.500000     0.355000        1.400000
# 75%         9.625000          0.570000     0.415000        1.500000
# max        12.200000          0.885000     0.590000        1.500000
#
#        chlorides  free sulfur dioxide  total sulfur dioxide    density  \
# count  48.000000            48.000000             48.000000  48.000000
# mean    0.071250            10.000000             22.166667   0.995811
# std     0.013192             6.526542             10.057988   0.001283
# min     0.042000             3.000000              6.000000   0.993310
# 25%     0.059000             5.750000             13.000000   0.994600
# 50%     0.070000             7.500000             23.000000   0.995550
# 75%     0.076750            14.250000             28.000000   0.996973
# max     0.096000            32.000000             42.000000   0.998000
#
#               pH  sulphates    alcohol
# count  48.000000  48.000000  48.000000
# mean    3.239375   0.611458  10.038889
# std     0.144140   0.112609   0.616608
# min     2.880000   0.450000   9.100000
# 25%     3.155000   0.520000   9.600000
# 50%     3.255000   0.600000   9.900000
# 75%     3.342500   0.700000  10.325000
# max     3.660000   0.890000  11.500000

# %%
minmax=preprocessing.MinMaxScaler(feature_range=(0,1))
x=minmax.fit_transform(x)
x=pd.DataFrame(x)
x.describe()
# Out:
#               0          1          2          3          4          5   \
# count  48.000000  48.000000  48.000000  48.000000  48.000000  48.000000
# mean    0.449811   0.432476   0.445621   0.729167   0.541667   0.241379
# std     0.283358   0.224706   0.334170   0.263243   0.244291   0.225053
# min     0.000000   0.000000   0.000000   0.000000   0.000000   0.000000
# 25%     0.253788   0.223404   0.093220   0.666667   0.314815   0.094828
# 50%     0.401515   0.453901   0.601695   0.666667   0.518519   0.155172
# 75%     0.609848   0.553191   0.703390   1.000000   0.643519   0.387931
# max     1.000000   1.000000   1.000000   1.000000   1.000000   1.000000
#
#               6          7          8          9          10
# count  48.000000  48.000000  48.000000  48.000000  48.000000
# mean    0.449074   0.533271   0.460737   0.366951   0.391204
# std     0.279389   0.273510   0.184794   0.255930   0.256920
# min     0.000000   0.000000   0.000000   0.000000   0.000000
# 25%     0.194444   0.275053   0.352564   0.159091   0.208333
# 50%     0.472222   0.477612   0.480769   0.340909   0.333333
# 75%     0.611111   0.780917   0.592949   0.568182   0.510417
# max     1.000000   1.000000   1.000000   1.000000   1.000000

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,random_state=42,test_size=0.2)
lr=linear_model.LinearRegression()
model=lr.fit(x_train,y_train)
pre=model.predict(x_test)
print('MSE is :',mean_squared_error(y_test,pre))
print('R error is ',r2_score(y_test,pre))
# Out:
# MSE is : 0.6209006720377866
# R error is  0.22387415995276672

# %%
x=df.drop('quality',axis=1)
x.describe()
# Out:
#        fixed acidity  volatile acidity  citric acid  residual sugar  \
# count      48.000000         48.000000    48.000000       48.000000
# mean        8.568750          0.484896     0.262917        1.418750
# std         1.870164          0.158418     0.197160        0.078973
# min         5.600000          0.180000     0.000000        1.200000
# 25%         7.275000          0.337500     0.055000        1.400000
# 50%         8.250000          0.500000     0.355000        1.400000
# 75%         9.625000          0.570000     0.415000        1.500000
# max        12.200000          0.885000     0.590000        1.500000
#
#        chlorides  free sulfur dioxide  total sulfur dioxide    density  \
# count  48.000000            48.000000             48.000000  48.000000
# mean    0.071250            10.000000             22.166667   0.995811
# std     0.013192             6.526542             10.057988   0.001283
# min     0.042000             3.000000              6.000000   0.993310
# 25%     0.059000             5.750000             13.000000   0.994600
# 50%     0.070000             7.500000             23.000000   0.995550
# 75%     0.076750            14.250000             28.000000   0.996973
# max     0.096000            32.000000             42.000000   0.998000
#
#               pH  sulphates    alcohol
# count  48.000000  48.000000  48.000000
# mean    3.239375   0.611458  10.038889
# std     0.144140   0.112609   0.616608
# min     2.880000   0.450000   9.100000
# 25%     3.155000   0.520000   9.600000
# 50%     3.255000   0.600000   9.900000
# 75%     3.342500   0.700000  10.325000
# max     3.660000   0.890000  11.500000

# %%
x=preprocessing.normalize(x)
x=pd.DataFrame(x)
x.describe()
# Out:
#               0          1          2          3          4          5   \
# count  48.000000  48.000000  48.000000  48.000000  48.000000  48.000000
# mean    0.328856   0.019036   0.009990   0.054887   0.002738   0.326725
# std     0.125129   0.009695   0.008086   0.018204   0.000967   0.117670
# min     0.133783   0.007465   0.000000   0.027144   0.001289   0.157067
# 25%     0.236244   0.010668   0.002542   0.042512   0.001919   0.230163
# 50%     0.307193   0.015871   0.010998   0.049945   0.002742   0.302768
# 75%     0.385743   0.024124   0.015527   0.069173   0.003427   0.432213
# max     0.686743   0.049178   0.027582   0.091933   0.004970   0.620445
#
#               6          7          8          9          10
# count  48.000000  48.000000  48.000000  48.000000  48.000000
# mean    0.738394   0.038576   0.125764   0.023275   0.388891
# std     0.139936   0.012578   0.041870   0.007383   0.131163
# min     0.337742   0.019280   0.057714   0.011246   0.201622
# 25%     0.670214   0.029770   0.096830   0.017067   0.292960
# 50%     0.795343   0.034922   0.116141   0.022684   0.346335
# 75%     0.829854   0.051426   0.171199   0.028688   0.502030
# max     0.917717   0.060956   0.205427   0.036040   0.660717

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,random_state=42,test_size=0.2)
lr=linear_model.LinearRegression()
model=lr.fit(x_train,y_train)
pre=model.predict(x_test)
print('MSE is :',mean_squared_error(y_test,pre))
print('R error is ',r2_score(y_test,pre))
# Out:
# MSE is : 0.7921349480880596
# R error is  0.009831314889925502

# %%
corematrix=df.corr()
plt.subplots(figsize=(20,8))
sns.heatmap(corematrix,vmin=-.7,vmax=0.7,annot=True,linewidths=0.2)
plt.show()

# %%
df.columns
# Out:
# Index(['fixed acidity', 'volatile acidity', 'citric acid', 'residual sugar',
#        'chlorides', 'free sulfur dioxide', 'total sulfur dioxide', 'density',
#        'pH', 'sulphates', 'alcohol', 'quality'],
#       dtype='object')
